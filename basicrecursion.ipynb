# %% [markdown]
# # Basic recursion
# # Copyright: Jagadeesh Vasudevamurthy
# # filename:basicrecursion.ipynb

# %% [markdown]
# # All import here

# %%
import sys # For getting Python Version

# %% [markdown]
# # Basic recursion class
# # You will write code only here

# %%
############################################################
# Recursion.py 
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2021
###########################################################

############################################################
#  All imports here
###########################################################

############################################################
#  class  test factorial
###########################################################    
class Recursion():
    def __init__(self):
        #Nothing can be added here
        pass

    ############################################################
    #          WRITE ALL YOUR PUBLIC FUNCTION BELOW
    ########################################################### 
    def factR(self,n):
        if n<=1:
            return 1
        else:
            return n* self.factR(n-1)
    
    def factI(self,n):
        fact=1
        for i in range(1,n+1):
            fact=fact*i
        return fact
    
    def printI(self,n,reverse='bool'):
        x=0
        if reverse==False:
            self._as_is_order(n)
        else:
            if n==0:
                print(n)
            else:
                while n:
                    x=n%10
                    n=n//10
                    print (x, end= " ")
            
    def printR(self,n,reverse='bool'):
        x=0
        if reverse==False:
            self._as_is_order(n)
        else:
            if n==0:
                print(n)
                exit
            else:
                x=n%10
                print (x, end= " ")
                return self.printR(n//10)
        
    def _as_is_order(self,n):
        x=str(n)
        for i in x:
            print (i,end=" ")
            
    def reverseI(self,n):
        s=0
        while (n!=0):
            s=10*s+(n%10)
            n=n//10
        return s
    
    def reverseR(self,n):
        s=0
        return self._reverseR(n,s)
    
            
    ############################################################
    #          WRITE ALL YOUR PRIVATE FUNCTION BELOW
    ########################################################### 
    
    def _reverseR(self,n,s):
        s=10*s+(n%10)
        if (n<10):
            return s
        else:
            return self._reverseR(n//10,s)

# %% [markdown]
# # Recursion test class
# # NOTHING CAN BE CHANGED BELOW

# %%
############################################################
# RecursionTest.py 
# Test Bench for Recursion
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2021
###########################################################

############################################################
#  NOTHING CAN BE CHANGED IN THIS FILE
########################################################### 

############################################################
#  All imports here
###########################################################
#import sys # For getting Python Version
# from Recursion import *

############################################################
#  class  test factorial
###########################################################    
class Test_fact():
    def __init__(self):
        self._test()

    def _test1(self,n:'int')->'void':
        o = Recursion()
        ans1 = o.factI(n)
        ans2 = o.factR(n)
        print("Fact(",n,") Iterative = ",ans1,sep="") ;
        print("Fact(",n,") Recursive = ",ans2,sep="") ;
        assert(ans1 == ans2)

    def _test(self):
        a = [0,1,5,10,20]
        for e in a:
            self._test1(e)

############################################################
#  class  test print asis
###########################################################    
class Test_print_asis_reverse():
    def __init__(self):
        self._test()

    def _test1(self,n:'int',reverse:'bool')->'void':
        o = Recursion()
        if (reverse):
            print(n, " in reverse order is as follows")
        else:
            print(n, " in asis order is as follows")
        print("Iterative")
        o.printI(n,reverse)
        print("Recursive")
        o.printR(n,reverse)

    def _test(self):
        a = [0,1,9,10,1986,1000, 1111,5267896714578]
        for e in a:
            self._test1(e,True)
        for e in a:
            self._test1(e,False)

############################################################
#  class  reverse int
###########################################################    
class Test_reverse():
    def __init__(self):
        self._test()

    def _test1(self,n:'int')->'void':
        o = Recursion()
        ans1 = o.reverseI(n)
        ans2 = o.reverseR(n)
        print("Reverse(",n,") Iterative = ",ans1,sep="") ;
        print("Reverse(",n,") Recursive = ",ans2,sep="") ;
        assert(ans1 == ans2)

    def _test(self):
        a = [0,1,9,10,1986,1000, 1111,5267896714578]
        for e in a:
            self._test1(e)

############################################################
#  class  test fib
###########################################################    
class Test_fib():
    def __init__(self):
        self._test()

    def _test1(self,n:'int')->'void':
        o = Recursion()
        ans1 = o.FibI(n)
        ans2 = o.FibR(n)
        print("Fib(",n,") Iterative = ",ans1,sep="") ;
        print("Fib(",n,") Recursive = ",ans2,sep="") ;
        assert(ans1 == ans2)

    def _test(self):
        a = [0,1,9,10,14,20]
        for e in a:
            self._test1(e)

############################################################
#  class  Test permutation
###########################################################    
class Test_permutation():
    def __init__(self):
        self._test()

    def _fact(self,n:'int')->'int':
        s = 1
        for i in range(2,n+1):
            s = s * i 
        return s

    def _test(self):
        N = 5
        for n in range(N):
           o = Recursion()
           print("Permutation of ",n, "are as follows");
           a = o.permR(n)
           print("Num permutation = ",a) ;
           #assert(a == self._fact(n))
  
 ############################################################
# MAIN
###########################################################    
def main():
    print("Basic Recursion test starts")
    print(sys.version)
    print("----------------Testing factorial--------------------")
    t = Test_fact()
    print("----------------Testing print asis/reverse--------------------")
    t = Test_print_asis_reverse()
    print("----------------Testing reverse--------------------")
    t = Test_reverse()
    if (False):
        print("----------------Testing Fibonacci--------------------")
        t = Test_fib()
        print("----------------Testing permutation by recursion--------------------")
        t = Test_permutation()
    print("Basic Recursion test Passed. If you don't see this line means, you cannot write Recursion")

# %%
main()
# Out:
# Basic Recursion test starts
# 3.8.8 (default, Apr 13 2021, 12:59:45)
# [Clang 10.0.0 ]
# ----------------Testing factorial--------------------
# Fact(0) Iterative = 1
# Fact(0) Recursive = 1
# Fact(1) Iterative = 1
# Fact(1) Recursive = 1
# Fact(5) Iterative = 120
# Fact(5) Recursive = 120
# Fact(10) Iterative = 3628800
# Fact(10) Recursive = 3628800
# Fact(20) Iterative = 2432902008176640000
# Fact(20) Recursive = 2432902008176640000
# ----------------Testing print asis/reverse--------------------
# 0  in reverse order is as follows
# Iterative
# 0
# Recursive
# 0
# 1  in reverse order is as follows
# Iterative
# 1 Recursive
# 1 0
# 9  in reverse order is as follows
# Iterative
# 9 Recursive
# 9 0
# 10  in reverse order is as follows
# Iterative
# 0 1 Recursive
# 0 1 0
# 1986  in reverse order is as follows
# Iterative
# 6 8 9 1 Recursive
# 6 8 9 1 0
# 1000  in reverse order is as follows
# Iterative
# 0 0 0 1 Recursive
# 0 0 0 1 0
# 1111  in reverse order is as follows
# Iterative
# 1 1 1 1 Recursive
# 1 1 1 1 0
# 5267896714578  in reverse order is as follows
# Iterative
# 8 7 5 4 1 7 6 9 8 7 6 2 5 Recursive
# 8 7 5 4 1 7 6 9 8 7 6 2 5 0
# 0  in asis order is as follows
# Iterative
# 0 Recursive
# 0 1  in asis order is as follows
# Iterative
# 1 Recursive
# 1 9  in asis order is as follows
# Iterative
# 9 Recursive
# 9 10  in asis order is as follows
# Iterative
# 1 0 Recursive
# 1 0 1986  in asis order is as follows
# Iterative
# 1 9 8 6 Recursive
# 1 9 8 6 1000  in asis order is as follows
# Iterative
# 1 0 0 0 Recursive
# 1 0 0 0 1111  in asis order is as follows
# Iterative
# 1 1 1 1 Recursive
# 1 1 1 1 5267896714578  in asis order is as follows
# Iterative
# 5 2 6 7 8 9 6 7 1 4 5 7 8 Recursive
# 5 2 6 7 8 9 6 7 1 4 5 7 8 ----------------Testing reverse--------------------
# Reverse(0) Iterative = 0
# Reverse(0) Recursive = 0
# Reverse(1) Iterative = 1
# Reverse(1) Recursive = 1
# Reverse(9) Iterative = 9
# Reverse(9) Recursive = 9
# Reverse(10) Iterative = 1
# Reverse(10) Recursive = 1
# Reverse(1986) Iterative = 6891
# Reverse(1986) Recursive = 6891
# Reverse(1000) Iterative = 1
# Reverse(1000) Recursive = 1
# Reverse(1111) Iterative = 1111
# Reverse(1111) Recursive = 1111
# Reverse(5267896714578) Iterative = 8754176987625
# Reverse(5267896714578) Recursive = 8754176987625
# Basic Recursion test Passed. If you don't see this line means, you cannot write Recursion
